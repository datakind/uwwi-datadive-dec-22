# %%
# Date: Dec 3, 2022
# Author: Sashka Warner
# Desc: Prep sites data for use in web app
import pandas as pd

# %%
# Load the site data
sites_raw = pd.read_csv("../../uwwi_datasets/uwwi_dataset_sites.csv")

# Inspect the data
sites_raw.head()
# Out:
#                       AgencySystem_Name  Agency_Id  Site_Id  Site_AgencyId  \
# 0        INTEGRATED COMMUNITY SOLUTIONS          1    414.0            1.0
# 1        INTEGRATED COMMUNITY SOLUTIONS          1    418.0            1.0
# 2                   INTERIM HEALTH CARE          2    419.0            2.0
# 3  zzinactive_INTERNATIONAL TRANSLATORS          3    420.0            3.0
# 4                JACKIE NITSCHKE CENTER          4    421.0            4.0
#
#                    Site_CreateStamp                    Site_EditStamp  \
# 0  2017-03-16T10:32:21.216012-05:00  2022-05-12T12:53:25.967449-05:00
# 1  2017-03-16T10:32:22.867221-05:00   2021-10-21T19:48:22.74763-05:00
# 2  2017-03-16T10:32:23.227182-05:00  2022-11-30T13:36:50.613023-06:00
# 3  2017-03-16T10:32:23.567045-05:00  2021-07-27T23:57:41.974815-05:00
# 4  2017-03-16T10:32:23.869975-05:00  2022-09-28T10:20:58.151543-05:00
#
#    Site_AuditStamp Site_Status SiteSystem_Active  \
# 0              NaN      active               Yes
# 1              NaN      active                No
# 2              NaN      active               Yes
# 3              NaN      active                No
# 4              NaN      active               Yes
#
#                                      SiteSystem_Name  ...  \
# 0                     INTEGRATED COMMUNITY SOLUTIONS  ...
# 1            ZZZINACTIVE LEAVING HOMELESSNESS BEHIND  ...
# 2                                INTERIM HEALTH CARE  ...
# 3  zzinactive_VILLA REAL DBA INTERNATIONAL TRANSL...  ...
# 4                             JACKIE NITSCHKE CENTER  ...
#
#   SiteAddressus_SiteAddressus_validated  \
# 0                                  True
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                  True
#
#   SiteAddressus_SiteAddressus_custom_location  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
#
#   SiteAddressus_SiteAddressus_zip_latitude  \
# 0                                44.489906
# 1                                44.489906
# 2                                44.542973
# 3                                44.483376
# 4                                44.483376
#
#   SiteAddressus_SiteAddressus_zip_longitude  \
# 0                                 -88.06991
# 1                                 -88.06991
# 2                                 -88.05582
# 3                                 -88.02269
# 4                                 -88.02269
#
#                          SiteAddressus_SiteAddressus  \
# 0     2605 S ONEIDA ST Suite 106 GREEN BAY WI, 54304
# 1  2605 South Oneida Street Suite 106 Green Bay W...
# 2  1600 Shawano Avenue Suite 201 Green Bay WI, 54303
# 3  529 South Jefferson Street Suite 203 Green Bay...
# 4              630 CHERRY STREET GREEN BAY WI, 54301
#
#   SiteOption_PermanentlyInactiveSite SiteOption_RecordOwner  \
# 0                                 []               ['BCUW']
# 1                                 []               ['BCUW']
# 2                                 []               ['BCUW']
# 3                                 []               ['BCUW']
# 4                                 []               ['BCUW']
#
#          SiteOption_Accessibility  \
# 0                              []
# 1                              []
# 2                              []
# 3  ['Elevators', 'Outside Ramps']
# 4                              []
#
#                      SiteCustom_NonStandardHoursText  \
# 0                           Monday-Friday 8am-4:30pm
# 1                       Monday-Friday, 8:00am-4:30pm
# 2                        Monday-Friday 8:30am-5:00pm
# 3  Monday-Friday, 8:00am-5:00pm; Interpreters ava...
# 4  Business hours: Monday-Thursday 7am-6:30pm; Fr...
#
#     SiteHoursofoperation_ModuleHoursofoperation.open
# 0  [{'day': -1, 'end_min': None, 'end_hour': None...
# 1  [{'day': -1, 'end_min': None, 'end_hour': None...
# 2  [{'day': -1, 'end_min': None, 'end_hour': None...
# 3  [{'day': -1, 'end_min': None, 'end_hour': None...
# 4  [{'day': -1, 'end_min': None, 'end_hour': None...
#
# [5 rows x 32 columns]

# %%
# Make a copy of the data
sites = sites_raw.copy()

# Extract columns of interest
sites = sites[[
    "AgencySystem_Name", 
    "SiteSystem_Name", 
    "Agency_Id", 
    "Site_Id",
    "Site_AgencyId", 
    "Site_Status", 
    "SiteAddressus_SiteAddressus_latitude", 
    "SiteAddressus_SiteAddressus_longitude", 
    "SiteAddressus_SiteAddressus_zip_latitude", 
    "SiteAddressus_SiteAddressus_zip_longitude", 
    "SiteAddressus_SiteAddressus",
    ]]

# Rename location columns
sites.rename(columns = {
    "SiteAddressus_SiteAddressus_latitude": "site_lat",
    "SiteAddressus_SiteAddressus_longitude": "site_long",
    "SiteAddressus_SiteAddressus_zip_latitude": "site_zip_lat",
    "SiteAddressus_SiteAddressus_zip_longitude": "site_zip_long",
    "SiteAddressus_SiteAddressus": "site_address",
}, inplace=True)
#sites.head()

# Check if lat/long data has nulls
#any(sites["site_lat"].isna())
#any(sites["site_long"].isna())

# Remove null lat/long records
sites.dropna(subset=["site_lat", "site_long"], inplace=True)

# Remove sites that have zero values for lat/long TODO: Go back and get zip long/lat if exists?
sites = sites[(sites["site_lat"] != 0) & (sites["site_long"] != 0)]

# Reset index after removing null and zero values
sites.reset_index(drop=True, inplace=True)

# Make sure no nulls exist
#any(sites["site_lat"].isna())
#any(sites["site_long"].isna())
#len(sites[sites["site_lat"] == 0])
#len(sites[sites["site_long"] == 0])

# Check that all of the lat/long data is of numeric type
#all(sites["site_lat"].apply(lambda x: isinstance(x, float)))
#ll(sites["site_long"].apply(lambda x: isinstance(x, float)))

# Check if any of the Site IDs have nulls
#any(sites["Site_Id"].isna())

# %%
# Check that all sites are active (even though some names have inactive?) TODO: ask about active status?
#sites["Site_Status"].unique()
# Out:
# array(['active'], dtype=object)

# %%
# Inspect the sites data
#print(sites.shape)

# Save to csv
sites.to_csv("uwwi_dataset_sites_cleaned.csv")

# %%
# Save to JSON
sites_json = sites[["SiteSystem_Name", "site_lat", "site_long"]]
sites_json.to_json("./getsites/data/sites.json", orient="index")
